# %%
import requests

# %%
import requests

url ='http://api.github.com/events'
response = requests.get(url)
print(response)
print(type(response))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
